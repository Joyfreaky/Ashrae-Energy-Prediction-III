# %% [markdown]
# # Install Kaggle and import dataset from kaggle, then unzip it.

# %%
# Uncomment and Run this cell if you are using colab, suggestion use github and gitpod, much faster and easier to use.
"""from google.colab import drive
drive.mount ('/content/gdrive')"""
# Out:
# "from google.colab import drive\ndrive.mount ('/content/gdrive')"

# %%
# If you are using requirements.txt, do not execute this cell
"""! pip install kaggle""" # Install kaggle api, Github Depandabot is configured to update this package.
# Out:
# '! pip install kaggle'

# %%
! mkdir -p ~/.kaggle/ && \
  echo '{"username":"joydipbhowmick","key":"498fb1b8fd7dff10274faf5933b9b60e"}' > ~/.kaggle/kaggle.json && \
  chmod 600 ~/.kaggle/kaggle.json # Create a new direcory, store the kaggle token key in that and make it read only to current user.

# %%
# Import the dataset using kaggle api and store in the data folder.
! kaggle competitions download -c ashrae-energy-prediction -p /home/joydipb/Ashrae-Energy-Prediction-III/data
# Out:
# ...
# 100%|████████████████████████████████████████| 379M/379M [00:11<00:00, 45.8MB/s]
# 100%|████████████████████████████████████████| 379M/379M [00:11<00:00, 33.1MB/s]

# %%
# Unzip the imported dataset in the data folder.
! unzip /home/joydipb/Ashrae-Energy-Prediction-III/data/ashrae-energy-prediction.zip -d /home/joydipb/Ashrae-Energy-Prediction-III/data
# Out:
# Archive:  /home/joydipb/Ashrae-Energy-Prediction-III/data/ashrae-energy-prediction.zip
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/building_metadata.csv
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/sample_submission.csv
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/test.csv
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/train.csv
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/weather_test.csv
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/weather_train.csv

# %%
# Historical Hourly Weather Data 2012-2017 (Kaggle) 
! kaggle datasets download -d selfishgene/historical-hourly-weather-data -p /home/joydipb/Ashrae-Energy-Prediction-III/data
# Out:
# ...
#  42%|███████████████▊                      | 5.00M/12.0M [00:00<00:00, 26.6MB/s]
# 100%|██████████████████████████████████████| 12.0M/12.0M [00:00<00:00, 42.3MB/s]

# %%
# Unzip the imported dataset in the data folder. 
! unzip /home/joydipb/Ashrae-Energy-Prediction-III/data/historical-hourly-weather-data.zip -d /home/joydipb/Ashrae-Energy-Prediction-III/data
# Out:
# Archive:  /home/joydipb/Ashrae-Energy-Prediction-III/data/historical-hourly-weather-data.zip
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/city_attributes.csv
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/humidity.csv
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/pressure.csv
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/temperature.csv
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/weather_description.csv
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/wind_direction.csv
#   inflating: /home/joydipb/Ashrae-Energy-Prediction-III/data/wind_speed.csv

# %%
# Clean the memory

import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# # Submitting the prediction file

# %%
# Edit the comments and file name before submission to kaggle.
! kaggle competitions submit -c ashrae-energy-prediction -f submission.csv -m "LightGBM without groupNUm median and Bulding Median"

# %% [markdown]
# # Code Snippet Github:

# %%
# Code snippets to be used for cloning a private repo from git.
! ls CMT307-Coursework-2-Group-19 > /dev/null 2> /dev/null || \
 git clone https://Joyfreaky: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@github.com/Joyfreaky/CMT307-Coursework-2-Group-19.git
