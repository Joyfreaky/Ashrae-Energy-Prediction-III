# %% [markdown]
# # Install Kaggle and import dataset from kaggle, then unzip it.

# %%
# Uncomment and Run this cell if you are using colab, suggestion use github and gitpod, much faster and easier to use.
"""from google.colab import drive
drive.mount ('/content/gdrive')"""
# Out:
# Mounted at /content/gdrive

# %%
# If you are using requirements.txt, do not execute this cell
"""! pip install kaggle""" # Install kaggle api, Github Depandabot is configured to update this package.
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.13.tar.gz (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.10 in /home/gitpod/.pyenv/versions/3.8.16/lib/python3.8/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /home/gitpod/.pyenv/versions/3.8.16/lib/python3.8/site-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: python-dateutil in /home/gitpod/.pyenv/versions/3.8.16/lib/python3.8/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /home/gitpod/.pyenv/versions/3.8.16/lib/python3.8/site-packages (from kaggle) (2.28.1)
# Collecting tqdm
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 24.5 MB/s eta 0:00:00
# Collecting python-slugify
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: urllib3 in /home/gitpod/.pyenv/versions/3.8.16/lib/python3.8/site-packages (from kaggle) (1.26.13)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 37.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/gitpod/.pyenv/versions/3.8.16/lib/python3.8/site-packages (from requests->kaggle) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.8.16/lib/python3.8/site-packages (from requests->kaggle) (3.4)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.13-py3-none-any.whl size=77716 sha256=72963c55d4dd622c2813da3054a740d0742a0f3d29d72a62c9a73537e91c0dfe
#   Stored in directory: /workspace/.pyenv_mirror/pip_cache/wheels/d5/1e/28/17c0af715c54936a8e32fedb6eebe8279772d0e7588450d15d
# Successfully built kaggle
# Installing collected packages: text-unidecode, tqdm, python-slugify, kaggle
# Successfully installed kaggle-1.5.13 python-slugify-8.0.1 text-unidecode-1.3 tqdm-4.65.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
! mkdir -p ~/.kaggle/ && \
  echo '{"username":"joydipbhowmick","key":"498fb1b8fd7dff10274faf5933b9b60e"}' > ~/.kaggle/kaggle.json && \
  chmod 600 ~/.kaggle/kaggle.json # Create a new direcory, store the kaggle token key in that and make it read only to current user.

# %%
# Import the dataset using kaggle api and store in the data folder outside the src folder.
! kaggle competitions download -c ashrae-energy-prediction -p data/
# Out:
# Downloading ashrae-energy-prediction.zip to data
# 100%|███████████████████████████████████████▉| 378M/379M [00:09<00:00, 41.9MB/s]
# 100%|████████████████████████████████████████| 379M/379M [00:09<00:00, 40.2MB/s]

# %%
# Unzip the imported dataset in the data folder.
! unzip data/ashrae-energy-prediction.zip -d data/
# Out:
# Archive:  data/ashrae-energy-prediction.zip
#   inflating: data/building_metadata.csv
#   inflating: data/sample_submission.csv
#   inflating: data/test.csv
#   inflating: data/train.csv
#   inflating: data/weather_test.csv
#   inflating: data/weather_train.csv

# %%
# Historical Hourly Weather Data 2012-2017 (Kaggle) 
! kaggle datasets download -d selfishgene/historical-hourly-weather-data -p data/
# Out:
# Downloading historical-hourly-weather-data.zip to data
#  67%|█████████████████████████▍            | 8.00M/12.0M [00:00<00:00, 14.2MB/s]
# 100%|██████████████████████████████████████| 12.0M/12.0M [00:00<00:00, 14.4MB/s]

# %%
# Unzip the imported dataset in the data folder. 
! unzip data/historical-hourly-weather-data.zip -d data/
# Out:
# Archive:  data/historical-hourly-weather-data.zip
#   inflating: data/city_attributes.csv
#   inflating: data/humidity.csv
#   inflating: data/pressure.csv
#   inflating: data/temperature.csv
#   inflating: data/weather_description.csv
#   inflating: data/wind_direction.csv
#   inflating: data/wind_speed.csv

# %%
# Clean the memory

import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# # Submitting the prediction file

# %%
# Edit the comments and file name before submission to kaggle.
! kaggle competitions submit -c ashrae-energy-prediction -f /workspace/Ashrae-Energy-Prediction-III/src/data/submission.csv -m "CNN Conv1D with Dense Layer on Best Features From LGBM k-fold"
# Out:
# 100%|████████████████████████████████████████| 681M/681M [01:29<00:00, 7.99MB/s]
# Successfully submitted to ASHRAE - Great Energy Predictor III

# %% [markdown]
# # Code Snippet Github:

# %%
# Code snippets to be used for cloning a private repo from git.
! ls CMT307-Coursework-2-Group-19 > /dev/null 2> /dev/null || \
 git clone https://Joyfreaky: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@github.com/Joyfreaky/CMT307-Coursework-2-Group-19.git
# Out:
# Cloning into 'CMT307-Coursework-2-Group-19'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 50 (delta 14), reused 23 (delta 6), pack-reused 0
# Unpacking objects: 100% (50/50), done.
